# %%
from IPython.display import display
from select_widget import get_dir

dropdown, info_label, get_dir = get_dir()

# Show the UI
display(dropdown, info_label)
# Out:
# Dropdown(description='Folder:', layout=Layout(width='300px'), options=('__pycache__', 'examples'), value='__py…
# Label(value='No folder selected yet')

# %%
selected_path = get_dir()
print("Tandem output:", selected_path)
# Out:
# Tandem output: /Users/j4yun/Library/CloudStorage/Dropbox/Codes/tandem-tools/visualization/examples

# %%
from pathlib import Path
from ipywidgets import Dropdown, Label

base_dir = Path("/Users/j4yun/Desktop/quakeworx/tandem")

# %%
for d in base_dir.iterdir():
    if d.is_dir():
        print(d.name)
# Out:
# visualization
# BP6_testrun
# GreensFunctions
# GMSHscript
# __pycache__
# for_training
# Tandem_uniform_dense
# Tandem_depthVarying_dense

# %%
job_names = sorted(
    [d.name for d in base_dir.iterdir() if d.is_dir()]
)

# %%
if '__pycache__' in job_names:
    print('yes')
    job_names.remove('__pycache__')
# Out:
# yes

# %%
job_names
# Out:
# ['BP6_testrun',
#  'GMSHscript',
#  'GreensFunctions',
#  'Tandem_depthVarying_dense',
#  'Tandem_uniform_dense',
#  'for_training',
#  'visualization']
